# %%
# Projet Azure DAM
# Analyse d'images avec Azure Computer Vision

print("Notebook prêt ")
# Out:
# Notebook prêt

# %%
# Imports Azure Computer Vision

from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from msrest.authentication import CognitiveServicesCredentials

print("Imports OK ")
# Out:
# Imports OK

# %%
# Configuration Azure (remplace par tes vraies clés)

KEY = "TA_CLE_API"
ENDPOINT = "TON_ENDPOINT"

print("Config OK ")
# Out:
# Config OK

# %%
# Simulation Azure Computer Vision

print("Description :")
print("a cat sitting on a couch")
# Out:
# Description :
# a cat sitting on a couch

# %%
print("Tags :")

tags = [
    ("cat", 0.99),
    ("animal", 0.98),
    ("pet", 0.97),
    ("indoor", 0.85)
]

for tag, score in tags:
    print(tag, score)
# Out:
# Tags :
# cat 0.99
# animal 0.98
# pet 0.97
# indoor 0.85

# %%
# NOTE :
# La connexion à Azure Cognitive Services nécessite un abonnement actif.
# N'ayant pas accès à un abonnement Azure, les résultats sont simulés.
# Cette simulation reproduit le comportement attendu de l'API Computer Vision.

# %%
## Analyse d'image avec Azure Computer Vision (simulation)
